# %%
# Packages
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib import pyplot
import numpy as np
import pandas as pd
import seaborn
from sklearn.impute import KNNImputer
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import LabelEncoder
import sys
# Open flood_tool package
sys.path.append('../..')
import flood_tool as ft
# Open functions from geo.py
sys.path.append('..')
from geo import get_gps_lat_long_from_easting_northing
from geo import get_easting_northing_from_gps_lat_long

# %% [markdown]
# ## Opening Dataset

# %%
# Open dataset
DF_orig = pd.read_csv("../resources/postcodes_labelled.csv")
DF_orig
# Out:
#        postcode  easting  northing          soilType  elevation  \
# 0      BA10 0AD   368289    134886  Unsurveyed/Urban         70
# 1      BA10 0AG   368240    134813  Unsurveyed/Urban         60
# 2      BA10 0AZ   367936    134742  Unsurveyed/Urban         60
# 3      BA10 0BB   367980    134623  Unsurveyed/Urban         60
# 4      BA10 0BH   367942    134697  Unsurveyed/Urban         60
# ...         ...      ...       ...               ...        ...
# 79995    W6 0SB   521913    178731  Unsurveyed/Urban         10
# 79996    W6 0XX   521848    178945  Unsurveyed/Urban         10
# 79997    W6 0XY   521796    179018  Unsurveyed/Urban         10
# 79998    W6 0YB   521889    178957  Unsurveyed/Urban         10
# 79999    W6 0YF   521862    179028  Unsurveyed/Urban         10
#
#       nearestWatercourse  distanceToWatercourse  localAuthority  riskLabel  \
# 0            Combe Brook                  770.0  South Somerset          3
# ...

# %%
# Calculate percentage of missing values in each column
missing = DF_orig.isnull().sum() / len(DF_orig)
missing
# Out:
# postcode                 0.000000
# easting                  0.000000
# northing                 0.000000
# soilType                 0.000000
# elevation                0.000000
# nearestWatercourse       0.392300
# distanceToWatercourse    0.000000
# localAuthority           0.000000
# riskLabel                0.000000
# medianPrice              0.000087
# historicallyFlooded      0.000000
# dtype: float64

# %%
# Create list of columns that will need imputing
columns_impute = list(missing[missing > 0.0].index)
columns_impute
# Out:
# ['nearestWatercourse', 'medianPrice']

# %% [markdown]
# ## Converting Coordinates

# %%
# Convert coordinates from easting and northing to longitude and longitude
def Convert_Coords(DF_orig):
    DF = DF_orig.copy()
# Get longitude latitude coordinates
    lats, lons = get_gps_lat_long_from_easting_northing(DF_orig['easting'], DF_orig['northing'])
# Add latitude longitude coordinates into dataframe
    DF['longitude'] = lons
    DF['latitude'] = lats
    return (DF)
# Apply function
DF_V1 = Convert_Coords(DF_orig)
DF_V1
# Out:
#        postcode  easting  northing          soilType  elevation  \
# 0      BA10 0AD   368289    134886  Unsurveyed/Urban         70
# 1      BA10 0AG   368240    134813  Unsurveyed/Urban         60
# 2      BA10 0AZ   367936    134742  Unsurveyed/Urban         60
# 3      BA10 0BB   367980    134623  Unsurveyed/Urban         60
# 4      BA10 0BH   367942    134697  Unsurveyed/Urban         60
# ...         ...      ...       ...               ...        ...
# 79995    W6 0SB   521913    178731  Unsurveyed/Urban         10
# 79996    W6 0XX   521848    178945  Unsurveyed/Urban         10
# 79997    W6 0XY   521796    179018  Unsurveyed/Urban         10
# 79998    W6 0YB   521889    178957  Unsurveyed/Urban         10
# 79999    W6 0YF   521862    179028  Unsurveyed/Urban         10
#
#       nearestWatercourse  distanceToWatercourse  localAuthority  riskLabel  \
# 0            Combe Brook                  770.0  South Somerset          3
# ...

# %% [markdown]
# ## Plotting Data

# %%
# Statistics
DF_V1.describe()
# Out:
#              easting       northing     elevation  distanceToWatercourse  \
# count   80000.000000   80000.000000  80000.000000           80000.000000
# mean   448242.209975  133712.121588     54.940250            1358.228625
# std    112164.286320   37444.052751     45.264274            1378.841484
# min     88907.000000   10216.000000    -10.000000               0.000000
# 25%    382871.000000  105901.750000     20.000000             610.000000
# 50%    473167.000000  139926.000000     40.000000            1040.000000
# 75%    528080.000000  166771.750000     80.000000            1700.000000
# max    639960.000000  210573.000000    430.000000           47600.000000
#
#           riskLabel   medianPrice  historicallyFlooded     longitude  \
# count  80000.000000  7.999300e+04         80000.000000  80000.000000
# mean       1.701588  4.781950e+05             0.022562     -1.306479
# std        1.211427  6.774985e+05             0.148505      1.595001
# ...

# %%
# Plot box plots for each numerical feature
Fig = pyplot.figure(figsize=(12,8))
Axis = Fig.add_subplot(4,2,1)
seaborn.boxplot(data=DF_V1[['longitude']], orient='h', color='limegreen')
Axis = Fig.add_subplot(4,2,3)
seaborn.boxplot(data=DF_V1[['latitude']], orient='h', color='deepskyblue')
Axis = Fig.add_subplot(4,2,5)
seaborn.boxplot(data=DF_V1[['elevation']], orient='h', color='darkorange')
Axis = Fig.add_subplot(4,2,7)
seaborn.boxplot(data=DF_V1[['distanceToWatercourse']], orient='h', color='mediumblue')
Axis = Fig.add_subplot(4,2,2)
seaborn.boxplot(data=DF_V1[['riskLabel']], orient='h', color='red')
Axis = Fig.add_subplot(4,2,4)
seaborn.boxplot(data=DF_V1[['historicallyFlooded']], orient='h', color='darkviolet')
Axis = Fig.add_subplot(4,2,6)
seaborn.boxplot(data=DF_V1[['medianPrice']], orient='h', color='gold')
# Out:
# <Axes: >

# %%
# Plot histograms
Fig = pyplot.figure(figsize=(16,8))
n = 1
Num_Vars = ['longitude', 'latitude', 'elevation', 'distanceToWatercourse', 'riskLabel', 'historicallyFlooded', 'medianPrice']
Bins = [30, 30, 30, 30, 7, 2, 30]
for Var in Num_Vars:
    Axis = Fig.add_subplot(2,4,n)
    if Var == 'riskLabel':
        Bins = np.arange(0.5,8.5,1)
    elif Var == 'historically_Flooded':
        Bins = [0,1]
    else:
        Bins = 30
    pyplot.hist(DF_V1[Var], bins=Bins, color='limegreen')
    n += 1
    pyplot.title(Var, fontsize=15)
    pyplot.grid(linewidth=0.3, color='silver', linestyle='-')
pyplot.show()

# %%
# Plot correlation heatmap
Fig = pyplot.figure(figsize=(10,6))
Corr = DF_V1[Num_Vars].corr()
seaborn.heatmap(Corr, xticklabels=Corr.columns, yticklabels=Corr.columns, cmap= "seismic", annot=Corr, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
# Plot map of locations of labelled postcodes
Fig = pyplot.figure(figsize=(9,5))
# Add coastlines and borders
Axis = Fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())
Axis.coastlines(linewidth=0.3)
Axis.add_feature(cfeature.BORDERS, linewidth=0.2)
# Plot stations
pyplot.scatter(DF_V1['longitude'], DF_V1['latitude'], c='limegreen', s=1.8)
# Formatting
x_Axis = np.arange(-7, 3, 1)
y_Axis = np.arange(49, 55, 1)
Axis.set_xlim(-7,2)
Axis.set_ylim(49,54)
Axis.set_xticks(x_Axis)
Axis.set_yticks(y_Axis)
Axis.set_title('Locations of Labelled Postcodes', fontsize=18)
Gridline = Axis.grid(linewidth=0.3, color='silver', linestyle='-')
pyplot.show()
# Out:
# /opt/anaconda3/envs/Kinen/lib/python3.13/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/Kinen/lib/python3.13/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %% [markdown]
# ## Getting Postcode District and Postcode Sector

# %%
# Function to get postcode district from postcode
def Postcode_District(Postcode):
# Normal scenario
    if " " in Postcode:
        Split = Postcode.split()
        District = Split[0].upper()
# Bad formatting
    else:
        Outward = Postcode[:-3].strip("_").strip("-").strip("+")
        District = Outward.upper()
    return (District)

# %%
# Function to get postcode sector from postcode
def Postcode_Sector(Postcode):
# Normal scenario
    if " " in Postcode:
        Split = Postcode.split()
        Outward = Split[0]
        Inward = Split[1]
        Sector = str(Outward + " " + Inward[0]).upper()
# Bad formatting
    else:
        Inward = Postcode[-3:]
        Outward = Postcode[:-3].strip("_").strip("-").strip("+")
        Sector = str(Outward + " " + Inward[0]).upper()
    return (Sector)

# %%
# Add postcode district and postcode sector into dataframe
def Add_Postcode_District_Sector(DF_orig):
    DF = DF_orig.copy()
    Districts = []
    Sectors = []
# Find postcode district and postcode sector for each postcode in dataframe
    for i in range(len(DF)):
        Districts.append(Postcode_District(DF['postcode'][i]))
        Sectors.append(Postcode_Sector(DF['postcode'][i]))
# Add new column to dataframe
    DF['postcodeDistrict'] = Districts
    DF['postcodeSector'] = Sectors
    return (DF)
# Apply function
DF_V2 = Add_Postcode_District_Sector(DF_V1)
DF_V2
# Out:
#        postcode  easting  northing          soilType  elevation  \
# 0      BA10 0AD   368289    134886  Unsurveyed/Urban         70
# 1      BA10 0AG   368240    134813  Unsurveyed/Urban         60
# 2      BA10 0AZ   367936    134742  Unsurveyed/Urban         60
# 3      BA10 0BB   367980    134623  Unsurveyed/Urban         60
# 4      BA10 0BH   367942    134697  Unsurveyed/Urban         60
# ...         ...      ...       ...               ...        ...
# 79995    W6 0SB   521913    178731  Unsurveyed/Urban         10
# 79996    W6 0XX   521848    178945  Unsurveyed/Urban         10
# 79997    W6 0XY   521796    179018  Unsurveyed/Urban         10
# 79998    W6 0YB   521889    178957  Unsurveyed/Urban         10
# 79999    W6 0YF   521862    179028  Unsurveyed/Urban         10
#
#       nearestWatercourse  distanceToWatercourse  localAuthority  riskLabel  \
# 0            Combe Brook                  770.0  South Somerset          3
# ...

# %%
# Test functions on mangled dataset
DF_mangled = pd.read_csv("../resources/example_data/postcodes_mangled.csv")
DF_mangled = Add_Postcode_District_Sector(DF_mangled)
DF_mangled
# Out:
#     postcode  easting  northing          soilType  elevation  \
# 0    po9 5ea   472101    108419  Unsurveyed/Urban         40
# 1   Ex15 3XE   313905    113519          Luvisols        130
# 2    PO144RJ   452325    106646  Unsurveyed/Urban         40
# 3  SE24  9UX   532008    174437  Unsurveyed/Urban         20
# 4   PL2  2YZ   250353     53862  Unsurveyed/Urban         10
# 5    gu222ws   500739    158609  Unsurveyed/Urban         40
# 6    SN8_1EA   418847    169121  Unsurveyed/Urban        130
# 7    SE2-0XP   546019    177982  Unsurveyed/Urban         20
# 8   RG12+1NB   486242    169497  Unsurveyed/Urban         60
# 9    SO1 8BJ   438705    115550  Unsurveyed/Urban         30
#
#   nearestWatercourse  distanceToWatercourse    localAuthority  \
# 0                NaN                 1530.0            Havant
# 1         River Culm                  310.0         Mid Devon
# 2                NaN                 1270.0           Fareham
# ...

# %% [markdown]
# ## Imputing Missing Data Based on Postcode Sector and District

# %%
# Default imputation constants
IMPUTATION_CONSTANTS = {"soilType": "Unsurveyed/Urban", "elevation": 60.0, "nearestWatercourse": "Unknown",\
"distanceToWatercourse": 80, "localAuthority": "Unknown"}

# %%
# Impute missing data using postcode sectors and districts
def Impute_Postcode_Method(DF_orig, DF_labelled, columns_impute):
    DF = DF_orig.copy()
# Seperate columns that need imputing into numerical and categorical
    columns_impute_num = list(DF_orig[columns_impute].select_dtypes(include=[np.number]).columns)
    columns_impute_cat = list(DF_orig[columns_impute].select_dtypes(exclude=[np.number]).columns)
#
# Numerical columns
    if len(columns_impute_num) > 0:
# Get medians of each postcode sector and postcode district from labelled dataset
        sector_medians = DF_labelled.groupby("postcodeSector")[columns_impute_num].median()
        district_medians = DF_labelled.groupby("postcodeDistrict")[columns_impute_num].median()
# Merge medians into new dataset
        DF = DF.merge(sector_medians, on="postcodeSector", how="left", suffixes=("", "_sector"))
        DF = DF.merge(district_medians, on="postcodeDistrict", how="left", suffixes=("", "_district"))
        for col in columns_impute_num:
# First try imputing with medians of postcode sector
            DF[col] = DF[col].fillna(DF[col+"_sector"])
# Then try imputing with medians of postcode district
            DF[col] = DF[col].fillna(DF[col+"_district"])
# If all else fails, impute with median of entire dataset
            DF[col] = DF[col].fillna(DF_labelled[col].median())
# Remove merging columns
            DF = DF.drop(columns=[col+"_sector", col+"_district"])
#
# Categorical columns
    if len(columns_impute_cat) > 0:
# Get modes of each postcode sector and postcode district from labelled dataset
        sector_modes = DF_labelled.dropna(subset=columns_impute_cat).groupby("postcodeSector")[columns_impute_cat].agg(lambda x: x.mode().iloc[0])
        district_modes = DF_labelled.dropna(subset=columns_impute_cat).groupby("postcodeDistrict")[columns_impute_cat].agg(lambda x: x.mode().iloc[0])
# Merge modes into new dataset
        DF = DF.merge(sector_modes, on="postcodeSector", how="left", suffixes=("", "_sector"))
        DF = DF.merge(district_modes, on="postcodeDistrict", how="left", suffixes=("", "_district"))
        for col in columns_impute_cat:
# First try imputing with modes of postcode sector
            DF[col] = DF[col].fillna(DF[col+"_sector"])
# Then try imputing with modes of postcode district
            DF[col] = DF[col].fillna(DF[col+"_district"])
# If all else fails, use default imputation constants
            DF[col] = DF[col].fillna(IMPUTATION_CONSTANTS[col])
# Remove merging columns
            DF = DF.drop(columns=[col+"_sector", col+"_district"])
    return (DF)

# %%
DF_postcode_method = Impute_Postcode_Method(DF_V2, DF_V2, columns_impute)
DF_postcode_method
# Out:
#        postcode  easting  northing          soilType  elevation  \
# 0      BA10 0AD   368289    134886  Unsurveyed/Urban         70
# 1      BA10 0AG   368240    134813  Unsurveyed/Urban         60
# 2      BA10 0AZ   367936    134742  Unsurveyed/Urban         60
# 3      BA10 0BB   367980    134623  Unsurveyed/Urban         60
# 4      BA10 0BH   367942    134697  Unsurveyed/Urban         60
# ...         ...      ...       ...               ...        ...
# 79995    W6 0SB   521913    178731  Unsurveyed/Urban         10
# 79996    W6 0XX   521848    178945  Unsurveyed/Urban         10
# 79997    W6 0XY   521796    179018  Unsurveyed/Urban         10
# 79998    W6 0YB   521889    178957  Unsurveyed/Urban         10
# 79999    W6 0YF   521862    179028  Unsurveyed/Urban         10
#
#       nearestWatercourse  distanceToWatercourse  localAuthority  riskLabel  \
# 0            Combe Brook                  770.0  South Somerset          3
# ...

# %%
# Calculate percentage of missing values in each column
missing = DF_postcode_method.isnull().sum() / len(DF_postcode_method)
missing
# Out:
# postcode                 0.0
# easting                  0.0
# northing                 0.0
# soilType                 0.0
# elevation                0.0
# nearestWatercourse       0.0
# distanceToWatercourse    0.0
# localAuthority           0.0
# riskLabel                0.0
# medianPrice              0.0
# historicallyFlooded      0.0
# longitude                0.0
# latitude                 0.0
# postcodeDistrict         0.0
# postcodeSector           0.0
# dtype: float64

# %% [markdown]
# ## Impute Missing Data Based on k Nearest Neighbours

# %%
# Impute missing data using k nearest neighbours
def Impute_KNN_Method(DF_orig, DF_labelled, columns_impute, k=5):
    DF = DF_orig.copy()
# Seperate columns that need imputing into numerical and categorical
    columns_impute_num = list(DF_orig[columns_impute].select_dtypes(include=[np.number]).columns)
    columns_impute_cat = list(DF_orig[columns_impute].select_dtypes(exclude=[np.number]).columns)
#
# Impute based on easting northing coordinates
    coords_labelled = np.array(DF_labelled[['easting', 'northing']])
    coords_new = np.array(DF[['easting', 'northing']])
# Fit nearest neighbours
    neighbors = NearestNeighbors(n_neighbors=k).fit(coords_labelled)
#
# Numerical columns
    if len(columns_impute_num) > 0:
        for col in columns_impute_num:
            vals = DF[col].values.copy()
            for i in range(len(DF)):
                if pd.isna(vals[i]):
# Find nearest neighbours within the labelled dataset
                    dists, indexes = neighbors.kneighbors([coords_new[i]])
                    neighbor_vals = pd.Series(DF_labelled[col][indexes[0]]).dropna()
# Impute with median of k neighbours
                    if len(neighbor_vals) > 0:
                        vals[i] = np.nanmedian(neighbor_vals)
# If no data for all k neighbours, impute with median of entire dataset
                    else:
                        vals[i] = np.nanmedian(DF_labelled[col])
# Replace column with imputed values
            DF[col] = vals
#
# Categorical columns
    if len(columns_impute_cat) > 0:
        for col in columns_impute_cat:
            vals = DF[col].values.copy()
            for i in range(len(DF)):
                if pd.isna(vals[i]):
# Find nearest neighbours within the labelled dataset
                    dists, indexes = neighbors.kneighbors([coords_new[i]])
                    neighbor_vals = pd.Series(DF_labelled[col][indexes[0]]).dropna()
# Impute with mode of k neighbours
                    if len(neighbor_vals) > 0:
                        vals[i] = neighbor_vals.mode().iloc[0]
# If no data for all k neighbours, use default imputation constants
                    else:
                        vals[i] = IMPUTATION_CONSTANTS[col]
# Replace column with imputed values
            DF[col] = vals
    return (DF)

# %%
DF_KNN = Impute_KNN_Method(DF_V2, DF_V2, columns_impute, 5)
DF_KNN
# Out:
#        postcode  easting  northing          soilType  elevation  \
# 0      BA10 0AD   368289    134886  Unsurveyed/Urban         70
# 1      BA10 0AG   368240    134813  Unsurveyed/Urban         60
# 2      BA10 0AZ   367936    134742  Unsurveyed/Urban         60
# 3      BA10 0BB   367980    134623  Unsurveyed/Urban         60
# 4      BA10 0BH   367942    134697  Unsurveyed/Urban         60
# ...         ...      ...       ...               ...        ...
# 79995    W6 0SB   521913    178731  Unsurveyed/Urban         10
# 79996    W6 0XX   521848    178945  Unsurveyed/Urban         10
# 79997    W6 0XY   521796    179018  Unsurveyed/Urban         10
# 79998    W6 0YB   521889    178957  Unsurveyed/Urban         10
# 79999    W6 0YF   521862    179028  Unsurveyed/Urban         10
#
#       nearestWatercourse  distanceToWatercourse  localAuthority  riskLabel  \
# 0            Combe Brook                  770.0  South Somerset          3
# ...

# %%
# Calculate percentage of missing values in each column
missing = DF_KNN.isnull().sum() / len(DF_KNN)
missing
# Out:
# postcode                 0.0
# easting                  0.0
# northing                 0.0
# soilType                 0.0
# elevation                0.0
# nearestWatercourse       0.0
# distanceToWatercourse    0.0
# localAuthority           0.0
# riskLabel                0.0
# medianPrice              0.0
# historicallyFlooded      0.0
# longitude                0.0
# latitude                 0.0
# postcodeDistrict         0.0
# postcodeSector           0.0
# dtype: float64

# %% [markdown]
# ## Reordering Columns

# %%
# List of current columns
current_columns = DF_postcode_method.columns
current_columns
# Out:
# Index(['postcode', 'easting', 'northing', 'soilType', 'elevation',
#        'nearestWatercourse', 'distanceToWatercourse', 'localAuthority',
#        'riskLabel', 'medianPrice', 'historicallyFlooded', 'longitude',
#        'latitude', 'postcodeDistrict', 'postcodeSector'],
#       dtype='object')

# %%
# Reorder columns
reorder_columns = ['postcode', 'postcodeDistrict', 'postcodeSector', 'easting', 'northing', 'longitude', 'latitude', 'soilType', \
'elevation', 'nearestWatercourse', 'distanceToWatercourse', 'localAuthority', 'riskLabel', 'medianPrice', 'historicallyFlooded']
DF_postcode_method_final = DF_postcode_method.copy()[reorder_columns]
DF_KNN_final = DF_KNN.copy()[reorder_columns]
DF_KNN_final
# Out:
#        postcode postcodeDistrict postcodeSector  easting  northing  longitude  \
# 0      BA10 0AD             BA10         BA10 0   368289    134886  -2.454381
# 1      BA10 0AG             BA10         BA10 0   368240    134813  -2.455075
# 2      BA10 0AZ             BA10         BA10 0   367936    134742  -2.459411
# 3      BA10 0BB             BA10         BA10 0   367980    134623  -2.458772
# 4      BA10 0BH             BA10         BA10 0   367942    134697  -2.459321
# ...         ...              ...            ...      ...       ...        ...
# 79995    W6 0SB               W6           W6 0   521913    178731  -0.245249
# 79996    W6 0XX               W6           W6 0   521848    178945  -0.246111
# 79997    W6 0XY               W6           W6 0   521796    179018  -0.246835
# 79998    W6 0YB               W6           W6 0   521889    178957  -0.245517
# 79999    W6 0YF               W6           W6 0   521862    179028  -0.245881
#
# ...

# %% [markdown]
# ## Outputting Preprocessed Data

# %%
# Define output directory
Output_Diri = '../resources/preprocessed_data/'

# %%
# Output preprocessed data as new csv file (impute using postcode method)
DF_postcode_method_final.to_csv(Output_Diri+'postcodes_impute_postcode_method.csv', index=False)

# %%
# Output preprocessed data as new csv file (impute using KNN)
DF_KNN_final.to_csv(Output_Diri+'postcodes_impute_KNN.csv', index=False)

# %% [markdown]
# ## Supplement
# Preprocessing for the processing of three damaged postcodes files in the example_data section

# %%
tool = ft.Tool()
DF_unlabelled = pd.read_csv("../resources/example_data/postcodes_unlabelled.csv")

DF_unlabelled
# Out:
#       postcode  easting  northing          soilType  elevation  \
# 0      PO9 5EA   472101    108419  Unsurveyed/Urban         40
# 1     EX15 3XE   313905    113519          Luvisols        130
# 2     PO14 4RJ   452325    106646  Unsurveyed/Urban         40
# 3     SE24 9UX   532008    174437  Unsurveyed/Urban         20
# 4     BS20 9PR   346765    176083  Unsurveyed/Urban         10
# ...        ...      ...       ...               ...        ...
# 9995  TN22 5HX   551700    120200          Luvisols         70
# 9996   RH2 0HH   526182    151672  Unsurveyed/Urban        120
# 9997   OX9 8BE   459900    196300          Luvisols         50
# 9998  EX14 9YT   321461    104539         Cambisols        210
# 9999   BA1 1WH   375350    164483  Unsurveyed/Urban         20
#
#      nearestWatercourse  distanceToWatercourse                localAuthority
# 0                   NaN                 1530.0                        Havant
# ...

# %%
DF_unlabelled.isnull().sum()
# Out:
# postcode                    0
# easting                     0
# northing                    0
# soilType                    0
# elevation                   0
# nearestWatercourse       3511
# distanceToWatercourse       0
# localAuthority              0
# dtype: int64

# %%
DF_unlabelled = Convert_Coords(DF_unlabelled)
DF_unlabelled_imputed = tool.impute_missing_values(DF_unlabelled)

# %%
DF_unlabelled_imputed.isnull().sum()
# Out:
# postcode                 0
# easting                  0
# northing                 0
# soilType                 0
# elevation                0
# nearestWatercourse       0
# distanceToWatercourse    0
# localAuthority           0
# postcodeDistrict         0
# postcodeSector           0
# dtype: int64

# %%
# Define output directory
Output_Diri = '../resources/preprocessed_data/example_data_preprocessed/'

# %%
DF_unlabelled_imputed.to_csv(Output_Diri+'postcodes_unlabelled_imputed.csv', index=False)

# %% [markdown]
# ### Missing Values Data

# %%
DF_missing = pd.read_csv("../resources/example_data/postcodes_missing_data.csv")

DF_missing
# Out:
#      postcode  easting  northing          soilType  elevation  \
# 0     RG6 3AP   475996    170644          Gleysols        NaN
# 1    DA11 9BB   561117    175837          Gleysols        0.0
# 2     BS5 6TQ   361138    175498  Unsurveyed/Urban        NaN
# 3     RG2 0HZ   471700    169500  Unsurveyed/Urban       40.0
# 4     DA4 0WE   553664    174039  Unsurveyed/Urban       20.0
# ..        ...      ...       ...               ...        ...
# 995  BN21 4DE   559875     99669  Unsurveyed/Urban        NaN
# 996  KT18 5BA   520934    160353  Unsurveyed/Urban       50.0
# 997  BN50 9XQ   531040    104624  Unsurveyed/Urban       30.0
# 998  BH22 8SG   408515     98030               NaN       20.0
# 999  PO36 0ET   459152     86140          Luvisols        NaN
#
#     nearestWatercourse  distanceToWatercourse     localAuthority
# 0         River Loddon                    NaN          Wokingham
# 1                  NaN                  210.0          Gravesham
# ...

# %%
DF_missing.isnull().sum()
# Out:
# postcode                   0
# easting                    0
# northing                   0
# soilType                 321
# elevation                327
# nearestWatercourse       562
# distanceToWatercourse    331
# localAuthority           317
# dtype: int64

# %%
DF_missing = Convert_Coords(DF_missing)
DF_missing_imputed = tool.impute_missing_values(DF_missing, method='knn')

# %%
DF_missing_imputed
# Out:
#      postcode  easting  northing          soilType  elevation  \
# 0     RG6 3AP   475996    170644          Gleysols       40.0
# 1    DA11 9BB   561117    175837          Gleysols        0.0
# 2     BS5 6TQ   361138    175498  Unsurveyed/Urban       20.0
# 3     RG2 0HZ   471700    169500  Unsurveyed/Urban       40.0
# 4     DA4 0WE   553664    174039  Unsurveyed/Urban       20.0
# ..        ...      ...       ...               ...        ...
# 995  BN21 4DE   559875     99669  Unsurveyed/Urban       20.0
# 996  KT18 5BA   520934    160353  Unsurveyed/Urban       50.0
# 997  BN50 9XQ   531040    104624  Unsurveyed/Urban       30.0
# 998  BH22 8SG   408515     98030  Unsurveyed/Urban       20.0
# 999  PO36 0ET   459152     86140          Luvisols       20.0
#
#     nearestWatercourse  distanceToWatercourse     localAuthority  \
# 0         River Loddon                  630.0          Wokingham
# 1         River Thames                  210.0          Gravesham
# ...

# %%
DF_missing_imputed.isnull().sum()
# Out:
# postcode                 0
# easting                  0
# northing                 0
# soilType                 0
# elevation                0
# nearestWatercourse       0
# distanceToWatercourse    0
# localAuthority           0
# postcodeDistrict         0
# postcodeSector           0
# dtype: int64

# %%
DF_missing_imputed.to_csv(Output_Diri+'postcodes_missing_data_imputed.csv', index=False)

# %% [markdown]
# ### Mangled Data

# %%
DF_mangled = pd.read_csv("../resources/example_data/postcodes_mangled.csv")

DF_mangled
# Out:
#     postcode  easting  northing          soilType  elevation  \
# 0    po9 5ea   472101    108419  Unsurveyed/Urban         40
# 1   Ex15 3XE   313905    113519          Luvisols        130
# 2    PO144RJ   452325    106646  Unsurveyed/Urban         40
# 3  SE24  9UX   532008    174437  Unsurveyed/Urban         20
# 4   PL2  2YZ   250353     53862  Unsurveyed/Urban         10
# 5    gu222ws   500739    158609  Unsurveyed/Urban         40
# 6    SN8_1EA   418847    169121  Unsurveyed/Urban        130
# 7    SE2-0XP   546019    177982  Unsurveyed/Urban         20
# 8   RG12+1NB   486242    169497  Unsurveyed/Urban         60
# 9    SO1 8BJ   438705    115550  Unsurveyed/Urban         30
#
#   nearestWatercourse  distanceToWatercourse    localAuthority
# 0                NaN                 1530.0            Havant
# 1         River Culm                  310.0         Mid Devon
# 2                NaN                 1270.0           Fareham
# ...

# %%
DF_mangled = Convert_Coords(DF_mangled)
DF_mangled['postcode'] = tool.get_postcode_district_sector(DF_mangled['postcode'])['postcode']

# %%
DF_mangled
# Out:
#    postcode  easting  northing          soilType  elevation  \
# 0   PO9 5EA   472101    108419  Unsurveyed/Urban         40
# 1  EX15 3XE   313905    113519          Luvisols        130
# 2  PO14 4RJ   452325    106646  Unsurveyed/Urban         40
# 3  SE24 9UX   532008    174437  Unsurveyed/Urban         20
# 4   PL2 2YZ   250353     53862  Unsurveyed/Urban         10
# 5  GU22 2WS   500739    158609  Unsurveyed/Urban         40
# 6   SN8 1EA   418847    169121  Unsurveyed/Urban        130
# 7   SE2 0XP   546019    177982  Unsurveyed/Urban         20
# 8  RG12 1NB   486242    169497  Unsurveyed/Urban         60
# 9   SO1 8BJ   438705    115550  Unsurveyed/Urban         30
#
#   nearestWatercourse  distanceToWatercourse    localAuthority  \
# 0                NaN                 1530.0            Havant
# 1         River Culm                  310.0         Mid Devon
# 2                NaN                 1270.0           Fareham
# ...

# %%
DF_mangled.isnull().sum()
# Out:
# postcode                 0
# easting                  0
# northing                 0
# soilType                 0
# elevation                0
# nearestWatercourse       4
# distanceToWatercourse    0
# localAuthority           0
# postcodeDistrict         0
# postcodeSector           0
# dtype: int64

# %%
DF_mangled_imputed = tool.impute_missing_values(DF_mangled, method='knn')

# %%
DF_mangled_imputed
# Out:
#    postcode  easting  northing          soilType  elevation  \
# 0   PO9 5EA   472101    108419  Unsurveyed/Urban         40
# 1  EX15 3XE   313905    113519          Luvisols        130
# 2  PO14 4RJ   452325    106646  Unsurveyed/Urban         40
# 3  SE24 9UX   532008    174437  Unsurveyed/Urban         20
# 4   PL2 2YZ   250353     53862  Unsurveyed/Urban         10
# 5  GU22 2WS   500739    158609  Unsurveyed/Urban         40
# 6   SN8 1EA   418847    169121  Unsurveyed/Urban        130
# 7   SE2 0XP   546019    177982  Unsurveyed/Urban         20
# 8  RG12 1NB   486242    169497  Unsurveyed/Urban         60
# 9   SO1 8BJ   438705    115550  Unsurveyed/Urban         30
#
#   nearestWatercourse  distanceToWatercourse    localAuthority  \
# 0          River Ems                 1530.0            Havant
# 1         River Culm                  310.0         Mid Devon
# 2         River Meon                 1270.0           Fareham
# ...

# %%
DF_mangled_imputed.to_csv(Output_Diri+'postcodes_mangled_imputed.csv', index=False)
